# %% [markdown]
# My test ran successfully in VS code. The output showed one dot ,which means the single line test passed. The summary line said "Ran 1 test in 0.000s" and ended with "OK". This means the function behaved just like the test ecpected. If the fucntion had returned the wrong value, the test would've shown a failure meesage.
