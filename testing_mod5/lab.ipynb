# %% [markdown]
# my unit test ran successsfully .The output showed one dot ,which indicates that the single line test passed.The summary line said "Ran 1 test in 0.000s" and ended with "OK". This means the function behaved exactly as the test expected. If the function had returned the wrong value, the test wouldve shown a failure message.
